# %% [markdown]
# # This file is part of  program Activ Spyder
# # Copyright © 2022  Carlo Oliveira <carlo@nce.ufrj.br>,
# # `Labase <http://labase.selfip.org/>`__; `GPL <http://is.gd/3Udt>`__.
# # SPDX-License-Identifier: (GPLv3-or-later AND LGPL-2.0-only) WITH bison-exception
#
# # Crawler for SuperGame -
#
#     Obtem versões dos relatórios dos games.
#
# .. codeauthor:: Carlo Oliveira <carlo@ufrj.br>
#
# Changelog
# ---------
# .. versionadded::    22.05
#         Criação do raspador de página.
#
# """

# %%
import pandas as pd
df = pd.read_json("../author_data.json")
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13 non-null     object
#  1   1       13 non-null     object
#  2   2       11 non-null     object
#  3   3       9 non-null      object
#  4   4       9 non-null      object
#  5   5       8 non-null      object
#  6   6       8 non-null      object
#  7   7       7 non-null      object
#  8   8       6 non-null      object
#  9   9       5 non-null      object
#  10  10      3 non-null      object
#  11  11      2 non-null      object
#  12  12      2 non-null      object
#  13  13      2 non-null      object
#  14  14      2 non-null      object
#  15  15      2 non-null      object
#  16  16      2 non-null      object
#  17  17      2 non-null      object
#  18  18      2 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 2.2+ KB
#                                                     0  \
# 0   {'author': 'Adrian ', 'version': 9, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 20, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 19, 'data_...
# 3   {'author': 'Eduardo ', 'version': 8, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 10, 'data_cr...
# 5   {'author': 'Leon ', 'version': 11, 'data_cri':...
# 6   {'author': 'Letícia ', 'version': 10, 'data_cr...
# 7   {'author': 'Miguel Tavares ', 'version': 5, 'd...
# 8   {'author': 'Alvaro ', 'version': 3, 'data_cri'...
# 9   {'author': 'Miguel Belmonte ', 'version': 2, '...
# 10  {'author': 'Diego Belmonte ', 'version': 2, 'd...
# 11  {'author': 'Isaque ', 'version': 3, 'data_cri'...
# 12  {'author': 'Arthur ', 'version': 7, 'data_cri'...
#
#                                                     1  \
# 0   {'author': 'Adrian ', 'version': 8, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 19, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 18, 'data_...
# 3   {'author': 'Eduardo ', 'version': 7, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 9, 'data_cri...
# 5   {'author': 'Leon ', 'version': 10, 'data_cri':...
# 6   {'author': 'Letícia ', 'version': 9, 'data_cri...
# 7   {'author': 'Miguel Tavares ', 'version': 4, 'd...
# 8   {'author': 'Alvaro ', 'version': 2, 'data_cri'...
# 9   {'author': 'Miguel Belmonte ', 'version': 1, '...
# 10  {'author': 'Diego Belmonte ', 'version': 1, 'd...
# 11  {'author': 'Isaque ', 'version': 2, 'data_cri'...
# 12  {'author': 'Arthur ', 'version': 6, 'data_cri'...
#
#                                                     2  \
# 0   {'author': 'Adrian ', 'version': 7, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 18, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 17, 'data_...
# 3   {'author': 'Eduardo ', 'version': 6, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 8, 'data_cri...
# 5   {'author': 'Leon ', 'version': 9, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 8, 'data_cri...
# 7   {'author': 'Miguel Tavares ', 'version': 3, 'd...
# 8   {'author': 'Alvaro ', 'version': 1, 'data_cri'...
# 9                                                None
# 10                                               None
# 11  {'author': 'Isaque ', 'version': 1, 'data_cri'...
# 12  {'author': 'Arthur ', 'version': 5, 'data_cri'...
#
#                                                     3  \
# 0   {'author': 'Adrian ', 'version': 6, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 17, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 16, 'data_...
# 3   {'author': 'Eduardo ', 'version': 5, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 7, 'data_cri...
# 5   {'author': 'Leon ', 'version': 8, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 7, 'data_cri...
# 7   {'author': 'Miguel Tavares ', 'version': 2, 'd...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12  {'author': 'Arthur ', 'version': 4, 'data_cri'...
#
#                                                     4  \
# 0   {'author': 'Adrian ', 'version': 5, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 16, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 15, 'data_...
# 3   {'author': 'Eduardo ', 'version': 4, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 6, 'data_cri...
# 5   {'author': 'Leon ', 'version': 7, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 6, 'data_cri...
# 7   {'author': 'Miguel Tavares ', 'version': 1, 'd...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12  {'author': 'Arthur ', 'version': 3, 'data_cri'...
#
#                                                     5  \
# 0   {'author': 'Adrian ', 'version': 4, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 15, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 14, 'data_...
# 3   {'author': 'Eduardo ', 'version': 3, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 5, 'data_cri...
# 5   {'author': 'Leon ', 'version': 6, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 5, 'data_cri...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12  {'author': 'Arthur ', 'version': 2, 'data_cri'...
#
#                                                     6  \
# 0   {'author': 'Adrian ', 'version': 3, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 14, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 13, 'data_...
# 3   {'author': 'Eduardo ', 'version': 2, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 4, 'data_cri...
# 5   {'author': 'Leon ', 'version': 5, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 4, 'data_cri...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12  {'author': 'Arthur ', 'version': 1, 'data_cri'...
#
#                                                     7  \
# 0   {'author': 'Adrian ', 'version': 2, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 13, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 12, 'data_...
# 3   {'author': 'Eduardo ', 'version': 1, 'data_cri...
# 4   {'author': 'Isabela ', 'version': 3, 'data_cri...
# 5   {'author': 'Leon ', 'version': 4, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 3, 'data_cri...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                     8  \
# 0   {'author': 'Adrian ', 'version': 1, 'data_cri'...
# 1   {'author': 'Adriana ', 'version': 12, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 11, 'data_...
# 3                                                None
# 4   {'author': 'Isabela ', 'version': 2, 'data_cri...
# 5   {'author': 'Leon ', 'version': 3, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 2, 'data_cri...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                     9  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 11, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 10, 'data_...
# 3                                                None
# 4   {'author': 'Isabela ', 'version': 1, 'data_cri...
# 5   {'author': 'Leon ', 'version': 2, 'data_cri': ...
# 6   {'author': 'Letícia ', 'version': 1, 'data_cri...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    10  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 10, 'data_cr...
# 2   {'author': 'Alexandro ', 'version': 9, 'data_c...
# 3                                                None
# 4                                                None
# 5   {'author': 'Leon ', 'version': 1, 'data_cri': ...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    11  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 9, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 8, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    12  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 8, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 7, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    13  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 7, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 6, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    14  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 6, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 5, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    15  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 5, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 4, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    16  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 4, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 3, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    17  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 3, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 2, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    18  \
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 2, 'data_cri...
# 2   {'author': 'Alexandro ', 'version': 1, 'data_c...
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                                    19
# 0                                                None
# 1   {'author': 'Adriana ', 'version': 1, 'data_cri...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None

# %%
import json
import csv
import bs4
# load data using Python JSON module

with open('../stopwords.txt','r') as f:
    stopwords = f.read().split()
def image_count(html):
    soup = bs4.BeautifulSoup(html)
    image_tags = soup.find_all('img')
    return len([img for img in image_tags if "/file/MATERIAIS.DESIGN.ARQUITETURA" in img['src']])
def word_count(html):
    soup = bs4.BeautifulSoup(html)
    text = soup.get_text()
    words = [word for word in text.split() if word not in stopwords]
    return len(words)

with open('../author_data.json','r') as f:
    data = json.loads(f.read())# Flatten data
headings = ["author",
"version",
"data_cri",
"data_alt",
"alterado_por",
"owner",
"txtsz",
"imgcnt",
"wordcnt",
"conteudo"]
datan = {key: [] for key in headings}
[datan[key].append(val) for aut in data for line in aut for key, val in line.items() if key in headings]
[datan["txtsz"].append(len(line["conteudo"])) for aut in data for line in aut]
[datan["imgcnt"].append(image_count(line["conteudo"])) for aut in data for line in aut]
[datan["wordcnt"].append(word_count(line["conteudo"])) for aut in data for line in aut]
# datan
with open('../author_data.csv','w') as fw:
    w = csv.DictWriter(fw, datan.keys())
    w.writeheader()
    w.writerow(datan)

df = pd.DataFrame(datan)
pd.to_datetime(df.data_cri) #, errors = 'ignore')
df.data_cri = pd.to_datetime(df.data_cri)
df.data_alt = pd.to_datetime(df.data_alt)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   author        109 non-null    object
#  1   version       109 non-null    int64
#  2   data_cri      109 non-null    datetime64[ns]
#  3   data_alt      109 non-null    datetime64[ns]
#  4   alterado_por  109 non-null    object
#  5   owner         109 non-null    object
#  6   txtsz         109 non-null    int64
#  7   imgcnt        109 non-null    int64
#  8   wordcnt       109 non-null    int64
#  9   conteudo      109 non-null    object
# dtypes: datetime64[ns](2), int64(4), object(4)
# memory usage: 8.6+ KB
#       author  version                   data_cri                   data_alt  \
# 0    Adrian         9 2021-12-22 16:56:57.600919 2022-04-13 19:00:46.490223
# 1    Adrian         8 2021-12-22 16:56:57.600919 2022-03-22 11:35:39.523721
# 2    Adrian         7 2021-12-22 16:56:57.600919 2022-01-28 16:36:19.080522
# 3    Adrian         6 2021-12-22 16:56:57.600919 2022-01-28 14:46:04.206159
# 4    Adrian         5 2021-12-22 16:56:57.600919 2022-01-12 18:59:49.565350
# ..       ...      ...                        ...                        ...
# 104  Arthur         5 2021-12-15 19:03:01.936861 2021-12-22 17:40:56.751238
# 105  Arthur         4 2021-12-15 19:03:01.936861 2021-12-22 15:49:13.921088
# 106  Arthur         3 2021-12-15 19:03:01.936861 2021-12-15 19:09:31.126127
# 107  Arthur         2 2021-12-15 19:03:01.936861 2021-12-15 19:05:19.332282
# 108  Arthur         1 2021-12-15 19:03:01.936861 2021-12-15 19:03:01.936861
#
#       alterado_por          owner  txtsz  imgcnt  wordcnt  \
# 0    vanessavianna  vanessavianna  13533      45      316
# 1    vanessavianna  vanessavianna  12648      40      316
# 2         Titoufrj  vanessavianna  12711      37      396
# 3    vanessavianna  vanessavianna  12107      37      316
# 4    vanessavianna  vanessavianna   9430      37      183
# ..             ...            ...    ...     ...      ...
# 104  vanessavianna  vanessavianna   3398       9      111
# 105  vanessavianna  vanessavianna   2168       2      117
# 106  vanessavianna  vanessavianna    893       2       11
# 107  vanessavianna  vanessavianna   3168      15        3
# 108  vanessavianna  vanessavianna   3095      15        2
#
#                                               conteudo
# 0    <html><body><h1 style="text-align: center;"><s...
# 1    <html><body><h1 style="text-align: center;"><s...
# 2    <html><body><h1 style="text-align: center;"><s...
# 3    <html><body><h1 style="text-align: center;"><s...
# 4    <html><body><h1 style="text-align: center;"><s...
# ..                                                 ...
# 104  <html><body><p style="text-align: center;"><st...
# 105  <html><body><p>Arthur - Processo criativo;</p>...
# 106  <html><body><p>Arthur - Processo criativo;</p>...
# 107  <html><body><p>Adrian - Processo criativo;</p>...
# 108  <html><body><p>Adrian - Desenhos </p>\n<p><img...
#
# [109 rows x 10 columns]

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f37a0cb5f40>]],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x="version", y="wordcnt", hue="author", data=df)
plt.gcf().set_size_inches(20, 10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x="version", y="imgcnt", hue="author", data=df)
plt.gcf().set_size_inches(20,10)
